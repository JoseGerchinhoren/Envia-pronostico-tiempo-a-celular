# %% [markdown]
# <img src=https://i.ytimg.com/vi/knxlmCVFAZI/maxresdefault.jpg>

# %%
#!pip3 install twilio

# %%
import os
from twilio.rest import Client
from twilio_config import *
import time

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


import pandas as pd
import requests
from bs4  import BeautifulSoup
from tqdm import tqdm

from datetime import datetime

# %% [markdown]
# # Armado de la URL

# %%
query = 'Salta'
api_key = API_KEY_WAPI

url_clima = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=1&aqi=no&alerts=no'
url_clima
# Out:
# 'http://api.weatherapi.com/v1/forecast.json?key=163ba65981e24602914183230231610&q=Salta&days=1&aqi=no&alerts=no'

# %%
response = requests.get(url_clima).json()

# %%
response
# Out:
# {'location': {'name': 'Salta',
#   'region': 'Salta',
#   'country': 'Argentina',
#   'lat': -24.78,
#   'lon': -65.42,
#   'tz_id': 'America/Argentina/Salta',
#   'localtime_epoch': 1697496737,
#   'localtime': '2023-10-16 19:52'},
#  'current': {'last_updated_epoch': 1697496300,
#   'last_updated': '2023-10-16 19:45',
#   'temp_c': 33.0,
#   'temp_f': 91.4,
#   'is_day': 0,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#    'code': 1003},
#   'wind_mph': 11.9,
#   'wind_kph': 19.1,
#   'wind_degree': 110,
#   'wind_dir': 'ESE',
#   'pressure_mb': 1010.0,
#   'pressure_in': 29.83,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 23,
#   'cloud': 25,
#   'feelslike_c': 32.1,
#   'feelslike_f': 89.8,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 8.0,
#   'gust_mph': 10.6,
#   'gust_kph': 17.0},
#  'forecast': {'forecastday': [{'date': '2023-10-16',
#     'date_epoch': 1697414400,
#     'day': {'maxtemp_c': 36.4,
#      'maxtemp_f': 97.5,
#      'mintemp_c': 16.7,
#      'mintemp_f': 62.0,
#      'avgtemp_c': 25.5,
#      'avgtemp_f': 77.9,
#      'maxwind_mph': 16.6,
#      'maxwind_kph': 26.6,
#      'totalprecip_mm': 1.73,
#      'totalprecip_in': 0.07,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 39.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 87,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 6.0},
#     'astro': {'sunrise': '06:47 AM',
#      'sunset': '07:28 PM',
#      'moonrise': '07:49 AM',
#      'moonset': '09:25 PM',
#      'moon_phase': 'Waxing Crescent',
#      'moon_illumination': '2',
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1697425200,
#       'time': '2023-10-16 00:00',
#       'temp_c': 18.3,
#       'temp_f': 65.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 269,
#       'wind_dir': 'W',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 6,
#       'feelslike_c': 18.3,
#       'feelslike_f': 65.0,
#       'windchill_c': 18.3,
#       'windchill_f': 65.0,
#       'heatindex_c': 18.3,
#       'heatindex_f': 65.0,
#       'dewpoint_c': 7.4,
#       'dewpoint_f': 45.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 1.0},
#      {'time_epoch': 1697428800,
#       'time': '2023-10-16 01:00',
#       'temp_c': 18.1,
#       'temp_f': 64.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 265,
#       'wind_dir': 'W',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 49,
#       'cloud': 4,
#       'feelslike_c': 18.1,
#       'feelslike_f': 64.6,
#       'windchill_c': 18.1,
#       'windchill_f': 64.6,
#       'heatindex_c': 18.1,
#       'heatindex_f': 64.6,
#       'dewpoint_c': 7.3,
#       'dewpoint_f': 45.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.9,
#       'gust_kph': 15.9,
#       'uv': 1.0},
#      {'time_epoch': 1697432400,
#       'time': '2023-10-16 02:00',
#       'temp_c': 17.7,
#       'temp_f': 63.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 260,
#       'wind_dir': 'W',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.73,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 50,
#       'cloud': 4,
#       'feelslike_c': 17.7,
#       'feelslike_f': 63.8,
#       'windchill_c': 17.7,
#       'windchill_f': 63.8,
#       'heatindex_c': 17.7,
#       'heatindex_f': 63.8,
#       'dewpoint_c': 7.2,
#       'dewpoint_f': 44.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.3,
#       'uv': 1.0},
#      {'time_epoch': 1697436000,
#       'time': '2023-10-16 03:00',
#       'temp_c': 17.3,
#       'temp_f': 63.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.72,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 4,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 17.3,
#       'windchill_f': 63.1,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.1,
#       'dewpoint_c': 7.1,
#       'dewpoint_f': 44.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0},
#      {'time_epoch': 1697439600,
#       'time': '2023-10-16 04:00',
#       'temp_c': 17.3,
#       'temp_f': 63.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 272,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 4,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.2,
#       'windchill_c': 17.3,
#       'windchill_f': 63.2,
#       'heatindex_c': 17.3,
#       'heatindex_f': 63.2,
#       'dewpoint_c': 7.4,
#       'dewpoint_f': 45.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0},
#      {'time_epoch': 1697443200,
#       'time': '2023-10-16 05:00',
#       'temp_c': 16.9,
#       'temp_f': 62.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 264,
#       'wind_dir': 'W',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 4,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.3,
#       'windchill_c': 16.9,
#       'windchill_f': 62.3,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.3,
#       'dewpoint_c': 7.1,
#       'dewpoint_f': 44.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 1.0},
#      {'time_epoch': 1697446800,
#       'time': '2023-10-16 06:00',
#       'temp_c': 16.7,
#       'temp_f': 62.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 265,
#       'wind_dir': 'W',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.73,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 51,
#       'cloud': 3,
#       'feelslike_c': 16.7,
#       'feelslike_f': 62.0,
#       'windchill_c': 16.7,
#       'windchill_f': 62.0,
#       'heatindex_c': 16.7,
#       'heatindex_f': 62.0,
#       'dewpoint_c': 6.6,
#       'dewpoint_f': 44.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 1.0},
#      {'time_epoch': 1697450400,
#       'time': '2023-10-16 07:00',
#       'temp_c': 17.0,
#       'temp_f': 62.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 262,
#       'wind_dir': 'W',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 52,
#       'cloud': 3,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.6,
#       'windchill_c': 17.0,
#       'windchill_f': 62.6,
#       'heatindex_c': 17.0,
#       'heatindex_f': 62.6,
#       'dewpoint_c': 7.1,
#       'dewpoint_f': 44.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.9,
#       'gust_kph': 15.9,
#       'uv': 5.0},
#      {'time_epoch': 1697454000,
#       'time': '2023-10-16 08:00',
#       'temp_c': 22.6,
#       'temp_f': 72.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 237,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.74,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 43,
#       'cloud': 2,
#       'feelslike_c': 24.3,
#       'feelslike_f': 75.8,
#       'windchill_c': 22.6,
#       'windchill_f': 72.7,
#       'heatindex_c': 24.3,
#       'heatindex_f': 75.8,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.4,
#       'uv': 6.0},
#      {'time_epoch': 1697457600,
#       'time': '2023-10-16 09:00',
#       'temp_c': 26.0,
#       'temp_f': 78.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 177,
#       'wind_dir': 'S',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.73,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 36,
#       'cloud': 3,
#       'feelslike_c': 25.8,
#       'feelslike_f': 78.4,
#       'windchill_c': 26.0,
#       'windchill_f': 78.7,
#       'heatindex_c': 25.8,
#       'heatindex_f': 78.4,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 7.0},
#      {'time_epoch': 1697461200,
#       'time': '2023-10-16 10:00',
#       'temp_c': 28.9,
#       'temp_f': 84.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 158,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1006.0,
#       'pressure_in': 29.71,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 31,
#       'cloud': 2,
#       'feelslike_c': 27.9,
#       'feelslike_f': 82.3,
#       'windchill_c': 28.9,
#       'windchill_f': 84.1,
#       'heatindex_c': 27.9,
#       'heatindex_f': 82.3,
#       'dewpoint_c': 10.2,
#       'dewpoint_f': 50.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 7.0},
#      {'time_epoch': 1697464800,
#       'time': '2023-10-16 11:00',
#       'temp_c': 31.3,
#       'temp_f': 88.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 156,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1005.0,
#       'pressure_in': 29.67,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 27,
#       'cloud': 2,
#       'feelslike_c': 29.9,
#       'feelslike_f': 85.8,
#       'windchill_c': 31.3,
#       'windchill_f': 88.3,
#       'heatindex_c': 29.9,
#       'heatindex_f': 85.8,
#       'dewpoint_c': 9.9,
#       'dewpoint_f': 49.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.6,
#       'gust_kph': 7.5,
#       'uv': 8.0},
#      {'time_epoch': 1697468400,
#       'time': '2023-10-16 12:00',
#       'temp_c': 33.9,
#       'temp_f': 93.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 140,
#       'wind_dir': 'SE',
#       'pressure_mb': 1004.0,
#       'pressure_in': 29.65,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 19,
#       'cloud': 3,
#       'feelslike_c': 31.9,
#       'feelslike_f': 89.4,
#       'windchill_c': 33.9,
#       'windchill_f': 93.0,
#       'heatindex_c': 31.9,
#       'heatindex_f': 89.4,
#       'dewpoint_c': 7.4,
#       'dewpoint_f': 45.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.7,
#       'uv': 8.0},
#      {'time_epoch': 1697472000,
#       'time': '2023-10-16 13:00',
#       'temp_c': 35.4,
#       'temp_f': 95.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 122,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1003.0,
#       'pressure_in': 29.61,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 17,
#       'cloud': 2,
#       'feelslike_c': 33.7,
#       'feelslike_f': 92.7,
#       'windchill_c': 35.4,
#       'windchill_f': 95.8,
#       'heatindex_c': 33.7,
#       'heatindex_f': 92.7,
#       'dewpoint_c': 6.3,
#       'dewpoint_f': 43.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 9.0},
#      {'time_epoch': 1697475600,
#       'time': '2023-10-16 14:00',
#       'temp_c': 36.4,
#       'temp_f': 97.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 116,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 15,
#       'cloud': 7,
#       'feelslike_c': 35.0,
#       'feelslike_f': 94.9,
#       'windchill_c': 36.4,
#       'windchill_f': 97.5,
#       'heatindex_c': 35.0,
#       'heatindex_f': 94.9,
#       'dewpoint_c': 5.3,
#       'dewpoint_f': 41.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.7,
#       'gust_kph': 12.4,
#       'uv': 9.0},
#      {'time_epoch': 1697479200,
#       'time': '2023-10-16 15:00',
#       'temp_c': 37.0,
#       'temp_f': 98.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 112,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.55,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 14,
#       'cloud': 21,
#       'feelslike_c': 35.7,
#       'feelslike_f': 96.2,
#       'windchill_c': 37.0,
#       'windchill_f': 98.5,
#       'heatindex_c': 35.7,
#       'heatindex_f': 96.2,
#       'dewpoint_c': 5.0,
#       'dewpoint_f': 41.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 9.0},
#      {'time_epoch': 1697482800,
#       'time': '2023-10-16 16:00',
#       'temp_c': 36.0,
#       'temp_f': 96.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 15.2,
#       'wind_kph': 24.5,
#       'wind_degree': 121,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1000.0,
#       'pressure_in': 29.53,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 16,
#       'cloud': 2,
#       'feelslike_c': 34.4,
#       'feelslike_f': 93.9,
#       'windchill_c': 36.0,
#       'windchill_f': 96.8,
#       'heatindex_c': 34.4,
#       'heatindex_f': 93.9,
#       'dewpoint_c': 6.7,
#       'dewpoint_f': 44.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.5,
#       'gust_kph': 28.2,
#       'uv': 9.0},
#      {'time_epoch': 1697486400,
#       'time': '2023-10-16 17:00',
#       'temp_c': 34.2,
#       'temp_f': 93.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 15.0,
#       'wind_kph': 24.1,
#       'wind_degree': 118,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1001.0,
#       'pressure_in': 29.57,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 20,
#       'cloud': 2,
#       'feelslike_c': 32.2,
#       'feelslike_f': 90.0,
#       'windchill_c': 34.2,
#       'windchill_f': 93.5,
#       'heatindex_c': 32.2,
#       'heatindex_f': 90.0,
#       'dewpoint_c': 7.9,
#       'dewpoint_f': 46.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 17.2,
#       'gust_kph': 27.8,
#       'uv': 8.0},
#      {'time_epoch': 1697490000,
#       'time': '2023-10-16 18:00',
#       'temp_c': 33.1,
#       'temp_f': 91.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 118,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1002.0,
#       'pressure_in': 29.6,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 23,
#       'cloud': 3,
#       'feelslike_c': 31.4,
#       'feelslike_f': 88.5,
#       'windchill_c': 33.1,
#       'windchill_f': 91.6,
#       'heatindex_c': 31.4,
#       'heatindex_f': 88.5,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.7,
#       'gust_kph': 23.6,
#       'uv': 8.0},
#      {'time_epoch': 1697493600,
#       'time': '2023-10-16 19:00',
#       'temp_c': 33.0,
#       'temp_f': 91.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 110,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1010.0,
#       'pressure_in': 29.83,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 23,
#       'cloud': 25,
#       'feelslike_c': 28.9,
#       'feelslike_f': 84.1,
#       'windchill_c': 30.3,
#       'windchill_f': 86.5,
#       'heatindex_c': 28.9,
#       'heatindex_f': 84.1,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.0,
#       'uv': 8.0},
#      {'time_epoch': 1697497200,
#       'time': '2023-10-16 20:00',
#       'temp_c': 26.6,
#       'temp_f': 79.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 0.4,
#       'wind_kph': 0.7,
#       'wind_degree': 359,
#       'wind_dir': 'N',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.73,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 34,
#       'cloud': 9,
#       'feelslike_c': 26.1,
#       'feelslike_f': 79.0,
#       'windchill_c': 26.6,
#       'windchill_f': 79.9,
#       'heatindex_c': 26.1,
#       'heatindex_f': 79.0,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 0.8,
#       'gust_kph': 1.3,
#       'uv': 1.0},
#      {'time_epoch': 1697500800,
#       'time': '2023-10-16 21:00',
#       'temp_c': 25.5,
#       'temp_f': 77.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 310,
#       'wind_dir': 'NW',
#       'pressure_mb': 1007.0,
#       'pressure_in': 29.75,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 36,
#       'cloud': 7,
#       'feelslike_c': 25.4,
#       'feelslike_f': 77.8,
#       'windchill_c': 25.5,
#       'windchill_f': 77.8,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.8,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 10.0,
#       'uv': 1.0},
#      {'time_epoch': 1697504400,
#       'time': '2023-10-16 22:00',
#       'temp_c': 24.6,
#       'temp_f': 76.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 299,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1008.0,
#       'pressure_in': 29.77,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 38,
#       'cloud': 6,
#       'feelslike_c': 25.0,
#       'feelslike_f': 77.0,
#       'windchill_c': 24.6,
#       'windchill_f': 76.4,
#       'heatindex_c': 25.0,
#       'heatindex_f': 77.0,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 12.0,
#       'uv': 1.0},
#      {'time_epoch': 1697508000,
#       'time': '2023-10-16 23:00',
#       'temp_c': 23.9,
#       'temp_f': 75.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 299,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1009.0,
#       'pressure_in': 29.79,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 40,
#       'cloud': 11,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 23.9,
#       'windchill_f': 75.0,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.3,
#       'gust_kph': 8.5,
#       'uv': 1.0}]}]}}

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %% [markdown]
# Vamos a concentrarnos en la seccion forecast.

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %% [markdown]
# Vamos a concentrarnos en el campo hora. Por si nos interesa saber a que hora del dia va a llover.

# %%
len(response['forecast']['forecastday'][0]['hour'])
# Out:
# 24

# %%
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[0] #Fecha
# Out:
# '2023-10-16'

# %%
int(response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]) #Hora
# Out:
# 1

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']['text'] #Condition
# Out:
# 'Clear'

# %%
response['forecast']['forecastday'][0]['hour'][0]['temp_c']
# Out:
# 18.3

# %%
response['forecast']['forecastday'][0]['hour'][0]['will_it_rain']
# Out:
# 0

# %%
response['forecast']['forecastday'][0]['hour'][0]['chance_of_rain']
# Out:
# 0

# %%
response['forecast']['forecastday'][0]['hour'][0]
# Out:
# {'time_epoch': 1697425200,
#  'time': '2023-10-16 00:00',
#  'temp_c': 18.3,
#  'temp_f': 65.0,
#  'is_day': 0,
#  'condition': {'text': 'Clear',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#   'code': 1000},
#  'wind_mph': 4.3,
#  'wind_kph': 6.8,
#  'wind_degree': 269,
#  'wind_dir': 'W',
#  'pressure_mb': 1009.0,
#  'pressure_in': 29.79,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 49,
#  'cloud': 6,
#  'feelslike_c': 18.3,
#  'feelslike_f': 65.0,
#  'windchill_c': 18.3,
#  'windchill_f': 65.0,
#  'heatindex_c': 18.3,
#  'heatindex_f': 65.0,
#  'dewpoint_c': 7.4,
#  'dewpoint_f': 45.3,
#  'will_it_rain': 0,
#  'chance_of_rain': 0,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 8.9,
#  'gust_kph': 14.4,
#  'uv': 1.0}

# %%
response['forecast']['forecastday'][0]['hour'][0]['time'].split()[0]
# Out:
# '2022-09-15'

# %%
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0]
# Out:
# '01'

# %%
response['forecast']['forecastday'][0]['hour'][0]['will_it_rain']
# Out:
# 0

# %%
response['forecast']['forecastday'][0]['hour'][2]['chance_of_rain']
# Out:
# 0

# %% [markdown]
# # Dataframe

# %%
def get_forecast(response,i):
    
    fecha = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hora = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condicion = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    tempe = float(recoresponserd['forecast']['forecastday'][0]['hour'][i]['temp_c'])
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']
    
    return fecha,hora,condicion,tempe,rain,prob_rain

# %%
datos = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])),colour = 'green'):
    
    datos.append(get_forecast(response,i))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 114260.27it/s]

# %%
datos[0]
# Out:
# ('2022-09-15', 0, 'Partly cloudy', 8.6, 0, 0)

# %%
col = ['Fecha','Hora','Condicion','Temperatura','Lluvia','prob_lluvia']
df = pd.DataFrame(datos,columns=col)
df = df.sort_values(by = 'Hora',ascending = True)
df
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  prob_lluvia
# 0   2022-09-15     0         Partly cloudy          8.6       0            0
# 1   2022-09-15     1  Patchy rain possible          8.4       0           60
# 2   2022-09-15     2         Partly cloudy          8.6       0            0
# 3   2022-09-15     3         Partly cloudy          8.5       0            0
# 4   2022-09-15     4         Partly cloudy          8.4       0            0
# 5   2022-09-15     5         Partly cloudy          8.1       0            0
# 6   2022-09-15     6         Partly cloudy          8.4       0            0
# 7   2022-09-15     7                 Sunny         12.1       0            0
# 8   2022-09-15     8                 Sunny         14.8       0            0
# 9   2022-09-15     9                 Sunny         17.2       0            0
# 10  2022-09-15    10                 Sunny         19.4       0            0
# 11  2022-09-15    11                 Sunny         21.0       0            0
# 12  2022-09-15    12  Patchy rain possible         19.8       0           60
# 13  2022-09-15    13                 Sunny         19.3       0            0
# 14  2022-09-15    14  Patchy rain possible         19.8       1           94
# 15  2022-09-15    15                 Sunny         18.7       0            0
# 16  2022-09-15    16  Patchy rain possible         18.5       1           88
# 17  2022-09-15    17                 Sunny         17.2       0            0
# 18  2022-09-15    18  Patchy rain possible         12.9       0           70
# 19  2022-09-15    19         Partly cloudy         11.4       0            0
# 20  2022-09-15    20         Partly cloudy         10.5       0            0
# 21  2022-09-15    21         Partly cloudy          9.7       0            0
# 22  2022-09-15    22         Partly cloudy          9.6       0            0
# 23  2022-09-15    23         Partly cloudy          9.5       0            0

# %%
# data_cli = {
#     'Fecha':datos[0][0],
#     'Hora':datos[1][],
#     'Tiempo':condicion,
#     'Temperatura':tempe,
#     'LLoverá':rain,
#     'prob_lluvia':prob_rain
    
# }

# df = pd.DataFrame(data_cli)
# df = df.sort_values(by = 'Hora',ascending = True)

# %%
df[df['Lluvia']==1]
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  prob_lluvia
# 14  2022-09-15    14  Patchy rain possible         19.8       1           94
# 16  2022-09-15    16  Patchy rain possible         18.5       1           88

# %%
df_rain =  df[(df['Lluvia']==1) & (df['Hora']>6) & (df['Hora']< 22)]
df_rain = df_rain[['Hora','Condicion']]
df_rain.set_index('Hora', inplace = True)

# %%
df['Fecha'][0]
# Out:
# '2022-09-15'

# %%
df_rain
# Out:
#                  Condicion
# Hora
# 14    Patchy rain possible
# 16    Patchy rain possible

# %%
'\nHola! \n\n\n El pronostico del tiempo hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain)
# Out:
# '\nHola! \n\n\n El pronostico del tiempo hoy 2022-09-15 en Bogotá es : \n\n\n                  Condicion\nHora                      \n14    Patchy rain possible\n16    Patchy rain possible'

# %%
PHONE_NUMBER
# Out:
# '+1 614 401 3161'

# %% [markdown]
# # Mensaje SMS desde Twilio

# %%
time.sleep(2)
account_sid = TWILIO_ACCOUNT_SID 
auth_token = TWILIO_AUTH_TOKEN

client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                     body='\nHola! \n\n\n El pronostico de lluvia hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain),
                     from_=PHONE_NUMBER,
                     to='+573222007879'
                 )

print('Mensaje Enviado ' + message.sid)
# Out:
# Mensaje Enviado SMbc309ab2afc09ea1f87a7eb64fb8fdda

# %% [markdown]
# # Challenge
#
# * Extrae el valor del dolar en tu país y el top 10 de criptomonedas con su respectiva valoración
# * Ahora envia un mensaje diarío a tu Whatsapp usando Twilio
#
# **hint 💡** Investiga que API's gratuitas existen para consultar estos datos
#
#
#
# <img src="WhatsApp Image 2022-09-13 at 9.12.18 AM.jpeg" width="200" height="200" />
